# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir('/content/drive/MyDrive/VKR_Malceva')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Data

# %%
print("="*60)
print("ЗАГРУЗКА И ПОДГОТОВКА ДАННЫХ ДЛЯ LIGHTGBM")
print("="*60)

# 1. Загрузка данных
print("1. Загрузка данных...")
train_df = pd.read_csv('./data/train_processed.csv')
val_df = pd.read_csv('./data/val_processed.csv')

# 2. Разделение на признаки и таргет
print("2. Разделение данных...")
X_train = train_df.drop(columns=['TARGET'])
y_train = train_df['TARGET']
X_val = val_df.drop(columns=['TARGET'])
y_val = val_df['TARGET']

# 3. Исправление названий столбцов для LightGBM
print("3. Исправление названий столбцов...")

def fix_column_names(df):
    """Исправляет названия столбцов для совместимости с LightGBM"""
    df_fixed = df.copy()
    new_columns = {}
    
    for col in df_fixed.columns:
        # Заменяем все не-буквенно-цифровые символы на подчеркивание
        new_name = str(col)
        # Заменяем пробелы и основные проблемные символы
        for char in [' ', '(', ')', '[', ']', '{', '}', '/', '\\', ':', ',', '.', '-', '+', '*', '&', '^', '%', '$', '#', '@', '!', '?']:
            new_name = new_name.replace(char, '_')
        
        # Убираем множественные подчеркивания
        while '__' in new_name:
            new_name = new_name.replace('__', '_')
        
        # Убираем подчеркивания в начале/конце
        new_name = new_name.strip('_')
        
        # Если имя пустое или начинается с цифры
        if not new_name:
            new_name = f'feature_{col}'
        elif new_name[0].isdigit():
            new_name = f'f_{new_name}'
        
        new_columns[col] = new_name
    
    return df_fixed.rename(columns=new_columns)

X_train = fix_column_names(X_train)
X_val = fix_column_names(X_val)

print(f"   Переименовано {X_train.shape[1]} столбцов")
print(f"   Пример: '{list(train_df.columns)[0]}' -> '{X_train.columns[0]}'")

# 4. Оптимизация типов данных
print("4. Оптимизация типов данных...")

# Целевая переменная -> int8
y_train = y_train.astype(np.int8)
y_val = y_val.astype(np.int8)

# Бинарные признаки (0/1) -> int8
binary_mask = (X_train.nunique() <= 2) & (X_train.isin([0, 1]).all())
binary_cols = X_train.columns[binary_mask].tolist()

if binary_cols:
    X_train[binary_cols] = X_train[binary_cols].astype(np.int8)
    X_val[binary_cols] = X_val[binary_cols].astype(np.int8)
    print(f"   Бинарных признаков: {len(binary_cols)} -> int8")

# Остальные признаки -> float32
other_cols = [col for col in X_train.columns if col not in binary_cols]
if other_cols:
    X_train[other_cols] = X_train[other_cols].astype(np.float32)
    X_val[other_cols] = X_val[other_cols].astype(np.float32)
    print(f"   Непрерывных признаков: {len(other_cols)} -> float32")

# 5. Удаление признаков с нулевой дисперсией
print("5. Удаление признаков с нулевой дисперсией...")
zero_var_cols = X_train.columns[X_train.std() == 0]
if len(zero_var_cols) > 0:
    X_train = X_train.drop(columns=zero_var_cols)
    X_val = X_val.drop(columns=zero_var_cols)
    print(f"   Удалено {len(zero_var_cols)} признаков с нулевой дисперсией")
else:
    print("   Признаков с нулевой дисперсией не найдено")

# 6. Очистка памяти
print("6. Очистка памяти...")
del train_df, val_df
import gc
gc.collect()

# 7. Итоговые результаты
print("\n" + "="*60)
print("ИТОГОВЫЕ РАЗМЕРЫ ДАННЫХ")
print("="*60)

print(f"X_train: {X_train.shape} (память: {X_train.memory_usage().sum()/1024**2:.1f} MB)")
print(f"X_val:   {X_val.shape} (память: {X_val.memory_usage().sum()/1024**2:.1f} MB)")
print(f"y_train: {y_train.shape} (тип: {y_train.dtype})")
print(f"y_val:   {y_val.shape} (тип: {y_val.dtype})")

print(f"\nТипы признаков в X_train:")
for dtype in X_train.dtypes.unique():
    count = (X_train.dtypes == dtype).sum()
    print(f"  {dtype}: {count} признаков")

print(f"\nПроверка пропущенных значений:")
print(f"  X_train: {X_train.isna().sum().sum()}")
print(f"  X_val:   {X_val.isna().sum().sum()}")

print(f"\nПримеры названий признаков:")
print(f"  {list(X_train.columns[:3])}")

print("\n" + "="*60)
print("ДАННЫЕ ГОТОВЫ ДЛЯ LIGHTGBM!")
print("="*60)
# Out:
# ============================================================
# ЗАГРУЗКА И ПОДГОТОВКА ДАННЫХ ДЛЯ LIGHTGBM
# ============================================================
# 1. Загрузка данных...
# 2. Разделение данных...
# 3. Исправление названий столбцов...
#    Переименовано 702 столбцов
#    Пример: 'SK_ID_CURR' -> 'SK_ID_CURR'
# 4. Оптимизация типов данных...
#    Бинарных признаков: 115 -> int8
#    Непрерывных признаков: 587 -> float32
# 5. Удаление признаков с нулевой дисперсией...
#    Удалено 5 признаков с нулевой дисперсией
# 6. Очистка памяти...
#
# ============================================================
# ИТОГОВЫЕ РАЗМЕРЫ ДАННЫХ
# ============================================================
# X_train: (184506, 697) (память: 432.5 MB)
# X_val:   (61502, 697) (память: 144.2 MB)
# y_train: (184506,) (тип: int8)
# y_val:   (61502,) (тип: int8)
#
# Типы признаков в X_train:
#   float32: 587 признаков
#   int8: 110 признаков
#
# Проверка пропущенных значений:
#   X_train: 0
#   X_val:   0
#
# Примеры названий признаков:
#   ['SK_ID_CURR', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL']
#
# ============================================================
# ДАННЫЕ ГОТОВЫ ДЛЯ LIGHTGBM!
# ============================================================

# %% [markdown]
# # LightGBM

# %%
print("="*80)
print("УСТАНОВКА И ИМПОРТ LIGHTGBM")
print("="*80)

# Устанавливаем LightGBM если ещё не установлен
try:
    import lightgbm as lgb
    print("✅ LightGBM уже установлен")
except:
    print("Устанавливаю LightGBM...")
    # !pip install lightgbm -q
    import lightgbm as lgb
    print("✅ LightGBM установлен")


from sklearn.model_selection import RandomizedSearchCV


print(f"\nДанные: X_train={X_train.shape}, X_val={X_val.shape}")
print(f"Тип данных: {X_train.dtypes.unique()}")
print(f"Целевая переменная: {y_train.unique()}")
# Out:
# ================================================================================
# УСТАНОВКА И ИМПОРТ LIGHTGBM
# ================================================================================
# ✅ LightGBM уже установлен
#
# Данные: X_train=(184506, 697), X_val=(61502, 697)
# Тип данных: [dtype('float32') dtype('int8')]
# Целевая переменная: [1 0]

# %%
print("="*80)
print("БЛОК 1: ПОИСК ЛУЧШИХ ГИПЕРПАРАМЕТРОВ LIGHTGBM")


# 1. Создаем базовую модель
print("\n1. Создание базовой модели LightGBM...")
base_lgb = lgb.LGBMClassifier(
    random_state=42,
    n_jobs=-1,            # Используем все ядра
    verbose=-1,           # Без вывода
    class_weight='balanced'  # Учитываем дисбаланс
)

# 2. Определяем сетку гиперпараметров для RandomizedSearchCV
print("\n2. Определение сетки гиперпараметров...")
param_distributions = {
    # Основные параметры
    'n_estimators': [100, 200, 300, 400, 500, 600, 800],
    'learning_rate': [0.01, 0.05, 0.1, 0.2, 0.3, 0.5],
    'num_leaves': [20, 31, 40, 50, 60, 70, 80, 100, 150],
    
    # Регуляризация
    'reg_alpha': [0, 0.01, 0.05, 0.1, 0.5, 1, 2, 5],  # L1
    'reg_lambda': [0, 0.01, 0.05, 0.1, 0.5, 1, 2, 5], # L2
    
    # Сэмплирование
    'subsample': [0.6, 0.7, 0.8, 0.9, 1.0],
    'colsample_bytree': [0.6, 0.7, 0.8, 0.9, 1.0],
    'subsample_freq': [0, 1, 5, 10],
    
    # Контроль переобучения
    'min_child_samples': [10, 20, 30, 40, 50, 100],
    'min_child_weight': [1e-5, 1e-3, 0.01, 0.1, 1],
    'min_split_gain': [0, 0.001, 0.01, 0.1],
    
    # Другие
    'max_depth': [-1, 5, 10, 15, 20, 25],  # -1 = без ограничений
    'boosting_type': ['gbdt', 'dart', 'goss'],  # Тип бустинга
    'importance_type': ['split', 'gain']  # Тип важности признаков
}

print(f"   Всего параметров для поиска: {sum(len(v) if isinstance(v, list) else 1 for v in param_distributions.values())}")

# 3. Настройка RandomizedSearchCV
print("\n3. Настройка RandomizedSearchCV...")
random_search = RandomizedSearchCV(
    estimator=base_lgb,
    param_distributions=param_distributions,
    n_iter=30,           # 30 случайных комбинаций
    cv=3,                # 3 фолда кросс-валидации
    scoring='roc_auc',   # Метрика для оптимизации
    n_jobs=1,            # LightGBM уже параллелит, тут ставим 1
    verbose=10,          # Детальный вывод прогресса
    random_state=42,
    refit=False,         # Пока не обучаем финальную модель
    return_train_score=True
)

# 4. Запуск поиска гиперпараметров
print("\n4. Запуск поиска лучших гиперпараметров...")
print(f"   Будет проверено {30 * 3} моделей (30 итераций × 3 фолда)")
print(f"   Размер данных: {X_train.shape}")
print(f"   Оценка времени: ~{30 * 3 * 0.5 / 60:.1f}-{30 * 3 * 2 / 60:.1f} минут (LightGBM очень быстрая!)")
print("-"*80)

import time
start_time = time.time()
random_search.fit(X_train, y_train)
search_time = time.time() - start_time

# 5. Результаты поиска
print("\n" + "="*80)
print("РЕЗУЛЬТАТЫ ПОИСКА ГИПЕРПАРАМЕТРОВ LIGHTGBM")
print("="*80)

print(f"Поиск завершен за {search_time/60:.1f} минут")
print(f"\nЛучшие параметры:")
for param, value in random_search.best_params_.items():
    print(f"  {param}: {value}")
print(f"\nЛучший ROC-AUC на кросс-валидации: {random_search.best_score_:.4f}")

# 6. Показываем топ-5 комбинаций параметров
print("\nТоп-5 лучших комбинаций параметров:")
results_df = pd.DataFrame(random_search.cv_results_)
top_results = results_df.sort_values('mean_test_score', ascending=False).head(5)

for i, (_, row) in enumerate(top_results.iterrows(), 1):
    params = row['params']
    print(f"\n{i}. Score: {row['mean_test_score']:.4f} (+/- {row['std_test_score']:.4f})")
    print(f"   n_estimators={params.get('n_estimators')}, learning_rate={params.get('learning_rate')}, "
          f"num_leaves={params.get('num_leaves')}")

print("\n" + "="*80)
print("СОХРАНЕНИЕ ЛУЧШИХ ПАРАМЕТРОВ ДЛЯ ЛОКАЛЬНОГО ОБУЧЕНИЯ")
print("="*80)

# 7. Сохраняем лучшие параметры в файл
best_params = random_search.best_params_

# Конвертируем типы для безопасности (LightGBM может быть чувствителен)
clean_best_params = {}
for key, value in best_params.items():
    # Преобразуем numpy типы в стандартные Python типы
    if isinstance(value, (np.integer, np.floating)):
        clean_best_params[key] = value.item()
    else:
        clean_best_params[key] = value

import json
import joblib

# Сохраняем в JSON (удобно для переноса)
with open('./models/lgb_best_params.json', 'w') as f:
    json.dump(clean_best_params, f, indent=2)

# Сохраняем весь объект поиска
search_results = {
    'best_params': clean_best_params,
    'best_score': random_search.best_score_,
    'cv_results': results_df.to_dict('records'),
    'search_time_minutes': search_time / 60
}

joblib.dump(search_results, './models/lgb_search_results.pkl')

print(f"\n✅ Лучшие параметры сохранены:")
print(f"   JSON: ./models/lgb_best_params.json")
print(f"   Полные результаты: ./models/lgb_search_results.pkl")
print(f"\nСкопируй эти параметры для обучения на своём компьютере!")
# Out:
# ================================================================================
# БЛОК 1: ПОИСК ЛУЧШИХ ГИПЕРПАРАМЕТРОВ LIGHTGBM
#
# 1. Создание базовой модели LightGBM...
#
# 2. Определение сетки гиперпараметров...
#    Всего параметров для поиска: 78
#
# 3. Настройка RandomizedSearchCV...
#
# 4. Запуск поиска лучших гиперпараметров...
#    Будет проверено 90 моделей (30 итераций × 3 фолда)
#    Размер данных: (184506, 697)
#    Оценка времени: ~0.8-3.0 минут (LightGBM очень быстрая!)
# --------------------------------------------------------------------------------
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# [CV 1/3; 1/30] START boosting_type=gbdt, colsample_bytree=0.7, importance_type=split, learning_rate=0.05, max_depth=15, min_child_samples=30, min_child_weight=0.01, min_split_gain=0.001, n_estimators=800, num_leaves=60, reg_alpha=0, reg_lambda=0, subsample=0.9, subsample_freq=5
# [CV 1/3; 1/30] END boosting_type=gbdt, colsample_bytree=0.7, importance_type=split, learning_rate=0.05, max_depth=15, min_child_samples=30, min_child_weight=0.01, min_split_gain=0.001, n_estimators=800, num_leaves=60, reg_alpha=0, reg_lambda=0, subsample=0.9, subsample_freq=5;, score=(train=0.996, test=0.761) total time= 3.0min
# [CV 2/3; 1/30] START boosting_type=gbdt, colsample_bytree=0.7, importance_type=split, learning_rate=0.05, max_depth=15, min_child_samples=30, min_child_weight=0.01, min_split_gain=0.001, n_estimators=800, num_leaves=60, reg_alpha=0, reg_lambda=0, subsample=0.9, subsample_freq=5
# [CV 2/3; 1/30] END boosting_type=gbdt, colsample_bytree=0.7, importance_type=split, learning_rate=0.05, max_depth=15, min_child_samples=30, min_child_weight=0.01, min_split_gain=0.001, n_estimators=800, num_leaves=60, reg_alpha=0, reg_lambda=0, subsample=0.9, subsample_freq=5;, score=(train=0.996, test=0.755) total time= 3.1min
# [CV 3/3; 1/30] START boosting_type=gbdt, colsample_bytree=0.7, importance_type=split, learning_rate=0.05, max_depth=15, min_child_samples=30, min_child_weight=0.01, min_split_gain=0.001, n_estimators=800, num_leaves=60, reg_alpha=0, reg_lambda=0, subsample=0.9, subsample_freq=5
# [CV 3/3; 1/30] END boosting_type=gbdt, colsample_bytree=0.7, importance_type=split, learning_rate=0.05, max_depth=15, min_child_samples=30, min_child_weight=0.01, min_split_gain=0.001, n_estimators=800, num_leaves=60, reg_alpha=0, reg_lambda=0, subsample=0.9, subsample_freq=5;, score=(train=0.996, test=0.763) total time= 3.0min
# [CV 1/3; 2/30] START boosting_type=gbdt, colsample_bytree=0.9, importance_type=gain, learning_rate=0.1, max_depth=-1, min_child_samples=100, min_child_weight=0.01, min_split_gain=0, n_estimators=600, num_leaves=100, reg_alpha=2, reg_lambda=0.5, subsample=0.7, subsample_freq=0
# [CV 1/3; 2/30] END boosting_type=gbdt, colsample_bytree=0.9, importance_type=gain, learning_rate=0.1, max_depth=-1, min_child_samples=100, min_child_weight=0.01, min_split_gain=0, n_estimators=600, num_leaves=100, reg_alpha=2, reg_lambda=0.5, subsample=0.7, subsample_freq=0;, score=(train=1.000, test=0.754) total time= 3.6min
# [CV 2/3; 2/30] START boosting_type=gbdt, colsample_bytree=0.9, importance_type=gain, learning_rate=0.1, max_depth=-1, min_child_samples=100, min_child_weight=0.01, min_split_gain=0, n_estimators=600, num_leaves=100, reg_alpha=2, reg_lambda=0.5, subsample=0.7, subsample_freq=0
# [CV 2/3; 2/30] END boosting_type=gbdt, colsample_bytree=0.9, importance_type=gain, learning_rate=0.1, max_depth=-1, min_child_samples=100, min_child_weight=0.01, min_split_gain=0, n_estimators=600, num_leaves=100, reg_alpha=2, reg_lambda=0.5, subsample=0.7, subsample_freq=0;, score=(train=1.000, test=0.747) total time= 3.5min
# [CV 3/3; 2/30] START boosting_type=gbdt, colsample_bytree=0.9, importance_type=gain, learning_rate=0.1, max_depth=-1, min_child_samples=100, min_child_weight=0.01, min_split_gain=0, n_estimators=600, num_leaves=100, reg_alpha=2, reg_lambda=0.5, subsample=0.7, subsample_freq=0
# [CV 3/3; 2/30] END boosting_type=gbdt, colsample_bytree=0.9, importance_type=gain, learning_rate=0.1, max_depth=-1, min_child_samples=100, min_child_weight=0.01, min_split_gain=0, n_estimators=600, num_leaves=100, reg_alpha=2, reg_lambda=0.5, subsample=0.7, subsample_freq=0;, score=(train=1.000, test=0.753) total time= 3.5min
# [CV 1/3; 3/30] START boosting_type=goss, colsample_bytree=0.8, importance_type=gain, learning_rate=0.5, max_depth=10, min_child_samples=10, min_child_weight=0.001, min_split_gain=0.01, n_estimators=600, num_leaves=50, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7, subsample_freq=5
# [CV 1/3; 3/30] END boosting_type=goss, colsample_bytree=0.8, importance_type=gain, learning_rate=0.5, max_depth=10, min_child_samples=10, min_child_weight=0.001, min_split_gain=0.01, n_estimators=600, num_leaves=50, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7, subsample_freq=5;, score=(train=nan, test=nan) total time=   9.8s
# [CV 2/3; 3/30] START boosting_type=goss, colsample_bytree=0.8, importance_type=gain, learning_rate=0.5, max_depth=10, min_child_samples=10, min_child_weight=0.001, min_split_gain=0.01, n_estimators=600, num_leaves=50, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7, subsample_freq=5
# [CV 2/3; 3/30] END boosting_type=goss, colsample_bytree=0.8, importance_type=gain, learning_rate=0.5, max_depth=10, min_child_samples=10, min_child_weight=0.001, min_split_gain=0.01, n_estimators=600, num_leaves=50, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7, subsample_freq=5;, score=(train=nan, test=nan) total time=  10.7s
# [CV 3/3; 3/30] START boosting_type=goss, colsample_bytree=0.8, importance_type=gain, learning_rate=0.5, max_depth=10, min_child_samples=10, min_child_weight=0.001, min_split_gain=0.01, n_estimators=600, num_leaves=50, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7, subsample_freq=5
# [CV 3/3; 3/30] END boosting_type=goss, colsample_bytree=0.8, importance_type=gain, learning_rate=0.5, max_depth=10, min_child_samples=10, min_child_weight=0.001, min_split_gain=0.01, n_estimators=600, num_leaves=50, reg_alpha=0.5, reg_lambda=0.5, subsample=0.7, subsample_freq=5;, score=(train=nan, test=nan) total time=  11.5s
# [CV 1/3; 4/30] START boosting_type=dart, colsample_bytree=0.7, importance_type=gain, learning_rate=0.01, max_depth=-1, min_child_samples=100, min_child_weight=0.001, min_split_gain=0.001, n_estimators=400, num_leaves=100, reg_alpha=0, reg_lambda=0.05, subsample=0.9, subsample_freq=0
# [CV 1/3; 4/30] END boosting_type=dart, colsample_bytree=0.7, importance_type=gain, learning_rate=0.01, max_depth=-1, min_child_samples=100, min_child_weight=0.001, min_split_gain=0.001, n_estimators=400, num_leaves=100, reg_alpha=0, reg_lambda=0.05, subsample=0.9, subsample_freq=0;, score=(train=0.825, test=0.756) total time= 5.2min
# [CV 2/3; 4/30] START boosting_type=dart, colsample_bytree=0.7, importance_type=gain, learning_rate=0.01, max_depth=-1, min_child_samples=100, min_child_weight=0.001, min_split_gain=0.001, n_estimators=400, num_leaves=100, reg_alpha=0, reg_lambda=0.05, subsample=0.9, subsample_freq=0
# [CV 2/3; 4/30] END boosting_type=dart, colsample_bytree=0.7, importance_type=gain, learning_rate=0.01, max_depth=-1, min_child_samples=100, min_child_weight=0.001, min_split_gain=0.001, n_estimators=400, num_leaves=100, reg_alpha=0, reg_lambda=0.05, subsample=0.9, subsample_freq=0;, score=(train=0.827, test=0.745) total time= 5.2min
# [CV 3/3; 4/30] START boosting_type=dart, colsample_bytree=0.7, importance_type=gain, learning_rate=0.01, max_depth=-1, min_child_samples=100, min_child_weight=0.001, min_split_gain=0.001, n_estimators=400, num_leaves=100, reg_alpha=0, reg_lambda=0.05, subsample=0.9, subsample_freq=0
# [CV 3/3; 4/30] END boosting_type=dart, colsample_bytree=0.7, importance_type=gain, learning_rate=0.01, max_depth=-1, min_child_samples=100, min_child_weight=0.001, min_split_gain=0.001, n_estimators=400, num_leaves=100, reg_alpha=0, reg_lambda=0.05, subsample=0.9, subsample_freq=0;, score=(train=0.823, test=0.756) total time= 5.2min
# [CV 1/3; 5/30] START boosting_type=goss, colsample_bytree=0.6, importance_type=gain, learning_rate=0.05, max_depth=10, min_child_samples=20, min_child_weight=0.1, min_split_gain=0.1, n_estimators=300, num_leaves=80, reg_alpha=0, reg_lambda=0.5, subsample=0.7, subsample_freq=10
# [CV 1/3; 5/30] END boosting_type=goss, colsample_bytree=0.6, importance_type=gain, learning_rate=0.05, max_depth=10, min_child_samples=20, min_child_weight=0.1, min_split_gain=0.1, n_estimators=300, num_leaves=80, reg_alpha=0, reg_lambda=0.5, subsample=0.7, subsample_freq=10;, score=(train=nan, test=nan) total time=  11.5s
# [CV 2/3; 5/30] START boosting_type=goss, colsample_bytree=0.6, importance_type=gain, learning_rate=0.05, max_depth=10, min_child_samples=20, min_child_weight=0.1, min_split_gain=0.1, n_estimators=300, num_leaves=80, reg_alpha=0, reg_lambda=0.5, subsample=0.7, subsample_freq=10
# [CV 2/3; 5/30] END boosting_type=goss, colsample_bytree=0.6, importance_type=gain, learning_rate=0.05, max_depth=10, min_child_samples=20, min_child_weight=0.1, min_split_gain=0.1, n_estimators=300, num_leaves=80, reg_alpha=0, reg_lambda=0.5, subsample=0.7, subsample_freq=10;, score=(train=nan, test=nan) total time=  10.1s
# [CV 3/3; 5/30] START boosting_type=goss, colsample_bytree=0.6, importance_type=gain, learning_rate=0.05, max_depth=10, min_child_samples=20, min_child_weight=0.1, min_split_gain=0.1, n_estimators=300, num_leaves=80, reg_alpha=0, reg_lambda=0.5, subsample=0.7, subsample_freq=10
# [CV 3/3; 5/30] END boosting_type=goss, colsample_bytree=0.6, importance_type=gain, learning_rate=0.05, max_depth=10, min_child_samples=20, min_child_weight=0.1, min_split_gain=0.1, n_estimators=300, num_leaves=80, reg_alpha=0, reg_lambda=0.5, subsample=0.7, subsample_freq=10;, score=(train=nan, test=nan) total time=  10.2s
# [CV 1/3; 6/30] START boosting_type=dart, colsample_bytree=0.7, importance_type=split, learning_rate=0.1, max_depth=-1, min_child_samples=20, min_child_weight=1e-05, min_split_gain=0.01, n_estimators=400, num_leaves=50, reg_alpha=0.05, reg_lambda=0.1, subsample=0.7, subsample_freq=1
# [CV 1/3; 6/30] END boosting_type=dart, colsample_bytree=0.7, importance_type=split, learning_rate=0.1, max_depth=-1, min_child_samples=20, min_child_weight=1e-05, min_split_gain=0.01, n_estimators=400, num_leaves=50, reg_alpha=0.05, reg_lambda=0.1, subsample=0.7, subsample_freq=1;, score=(train=0.901, test=0.775) total time= 3.7min
# [CV 2/3; 6/30] START boosting_type=dart, colsample_bytree=0.7, importance_type=split, learning_rate=0.1, max_depth=-1, min_child_samples=20, min_child_weight=1e-05, min_split_gain=0.01, n_estimators=400, num_leaves=50, reg_alpha=0.05, reg_lambda=0.1, subsample=0.7, subsample_freq=1
# [CV 2/3; 6/30] END boosting_type=dart, colsample_bytree=0.7, importance_type=split, learning_rate=0.1, max_depth=-1, min_child_samples=20, min_child_weight=1e-05, min_split_gain=0.01, n_estimators=400, num_leaves=50, reg_alpha=0.05, reg_lambda=0.1, subsample=0.7, subsample_freq=1;, score=(train=0.902, test=0.766) total time= 3.8min
# [CV 3/3; 6/30] START boosting_type=dart, colsample_bytree=0.7, importance_type=split, learning_rate=0.1, max_depth=-1, min_child_samples=20, min_child_weight=1e-05, min_split_gain=0.01, n_estimators=400, num_leaves=50, reg_alpha=0.05, reg_lambda=0.1, subsample=0.7, subsample_freq=1
# [CV 3/3; 6/30] END boosting_type=dart, colsample_bytree=0.7, importance_type=split, learning_rate=0.1, max_depth=-1, min_child_samples=20, min_child_weight=1e-05, min_split_gain=0.01, n_estimators=400, num_leaves=50, reg_alpha=0.05, reg_lambda=0.1, subsample=0.7, subsample_freq=1;, score=(train=0.900, test=0.773) total time= 3.7min
# [CV 1/3; 7/30] START boosting_type=gbdt, colsample_bytree=0.9, importance_type=gain, learning_rate=0.2, max_depth=20, min_child_samples=10, min_child_weight=0.001, min_split_gain=0.1, n_estimators=500, num_leaves=100, reg_alpha=0.01, reg_lambda=0, subsample=0.6, subsample_freq=0
# [CV 1/3; 7/30] END boosting_type=gbdt, colsample_bytree=0.9, importance_type=gain, learning_rate=0.2, max_depth=20, min_child_samples=10, min_child_weight=0.001, min_split_gain=0.1, n_estimators=500, num_leaves=100, reg_alpha=0.01, reg_lambda=0, subsample=0.6, subsample_freq=0;, score=(train=1.000, test=0.720) total time= 3.3min
# [CV 2/3; 7/30] START boosting_type=gbdt, colsample_bytree=0.9, importance_type=gain, learning_rate=0.2, max_depth=20, min_child_samples=10, min_child_weight=0.001, min_split_gain=0.1, n_estimators=500, num_leaves=100, reg_alpha=0.01, reg_lambda=0, subsample=0.6, subsample_freq=0
# [CV 2/3; 7/30] END boosting_type=gbdt, colsample_bytree=0.9, importance_type=gain, learning_rate=0.2, max_depth=20, min_child_samples=10, min_child_weight=0.001, min_split_gain=0.1, n_estimators=500, num_leaves=100, reg_alpha=0.01, reg_lambda=0, subsample=0.6, subsample_freq=0;, score=(train=1.000, test=0.720) total time= 3.3min
# [CV 3/3; 7/30] START boosting_type=gbdt, colsample_bytree=0.9, importance_type=gain, learning_rate=0.2, max_depth=20, min_child_samples=10, min_child_weight=0.001, min_split_gain=0.1, n_estimators=500, num_leaves=100, reg_alpha=0.01, reg_lambda=0, subsample=0.6, subsample_freq=0
# [CV 3/3; 7/30] END boosting_type=gbdt, colsample_bytree=0.9, importance_type=gain, learning_rate=0.2, max_depth=20, min_child_samples=10, min_child_weight=0.001, min_split_gain=0.1, n_estimators=500, num_leaves=100, reg_alpha=0.01, reg_lambda=0, subsample=0.6, subsample_freq=0;, score=(train=1.000, test=0.723) total time= 3.3min
# [CV 1/3; 8/30] START boosting_type=dart, colsample_bytree=0.7, importance_type=split, learning_rate=0.1, max_depth=10, min_child_samples=100, min_child_weight=1, min_split_gain=0.001, n_estimators=300, num_leaves=60, reg_alpha=2, reg_lambda=0.1, subsample=0.6, subsample_freq=0
# [CV 1/3; 8/30] END boosting_type=dart, colsample_bytree=0.7, importance_type=split, learning_rate=0.1, max_depth=10, min_child_samples=100, min_child_weight=1, min_split_gain=0.001, n_estimators=300, num_leaves=60, reg_alpha=2, reg_lambda=0.1, subsample=0.6, subsample_freq=0;, score=(train=0.896, test=0.771) total time= 2.8min
# [CV 2/3; 8/30] START boosting_type=dart, colsample_bytree=0.7, importance_type=split, learning_rate=0.1, max_depth=10, min_child_samples=100, min_child_weight=1, min_split_gain=0.001, n_estimators=300, num_leaves=60, reg_alpha=2, reg_lambda=0.1, subsample=0.6, subsample_freq=0
# [CV 2/3; 8/30] END boosting_type=dart, colsample_bytree=0.7, importance_type=split, learning_rate=0.1, max_depth=10, min_child_samples=100, min_child_weight=1, min_split_gain=0.001, n_estimators=300, num_leaves=60, reg_alpha=2, reg_lambda=0.1, subsample=0.6, subsample_freq=0;, score=(train=0.898, test=0.766) total time= 2.8min
# [CV 3/3; 8/30] START boosting_type=dart, colsample_bytree=0.7, importance_type=split, learning_rate=0.1, max_depth=10, min_child_samples=100, min_child_weight=1, min_split_gain=0.001, n_estimators=300, num_leaves=60, reg_alpha=2, reg_lambda=0.1, subsample=0.6, subsample_freq=0
# [CV 3/3; 8/30] END boosting_type=dart, colsample_bytree=0.7, importance_type=split, learning_rate=0.1, max_depth=10, min_child_samples=100, min_child_weight=1, min_split_gain=0.001, n_estimators=300, num_leaves=60, reg_alpha=2, reg_lambda=0.1, subsample=0.6, subsample_freq=0;, score=(train=0.895, test=0.775) total time= 2.9min
# [CV 1/3; 9/30] START boosting_type=gbdt, colsample_bytree=0.9, importance_type=split, learning_rate=0.1, max_depth=20, min_child_samples=100, min_child_weight=0.01, min_split_gain=0.01, n_estimators=100, num_leaves=31, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8, subsample_freq=5
# [CV 1/3; 9/30] END boosting_type=gbdt, colsample_bytree=0.9, importance_type=split, learning_rate=0.1, max_depth=20, min_child_samples=100, min_child_weight=0.01, min_split_gain=0.01, n_estimators=100, num_leaves=31, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8, subsample_freq=5;, score=(train=0.854, test=0.773) total time=  35.4s
# [CV 2/3; 9/30] START boosting_type=gbdt, colsample_bytree=0.9, importance_type=split, learning_rate=0.1, max_depth=20, min_child_samples=100, min_child_weight=0.01, min_split_gain=0.01, n_estimators=100, num_leaves=31, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8, subsample_freq=5
# [CV 2/3; 9/30] END boosting_type=gbdt, colsample_bytree=0.9, importance_type=split, learning_rate=0.1, max_depth=20, min_child_samples=100, min_child_weight=0.01, min_split_gain=0.01, n_estimators=100, num_leaves=31, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8, subsample_freq=5;, score=(train=0.856, test=0.764) total time=  33.6s
# [CV 3/3; 9/30] START boosting_type=gbdt, colsample_bytree=0.9, importance_type=split, learning_rate=0.1, max_depth=20, min_child_samples=100, min_child_weight=0.01, min_split_gain=0.01, n_estimators=100, num_leaves=31, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8, subsample_freq=5
# [CV 3/3; 9/30] END boosting_type=gbdt, colsample_bytree=0.9, importance_type=split, learning_rate=0.1, max_depth=20, min_child_samples=100, min_child_weight=0.01, min_split_gain=0.01, n_estimators=100, num_leaves=31, reg_alpha=0.5, reg_lambda=0.5, subsample=0.8, subsample_freq=5;, score=(train=0.854, test=0.772) total time=  35.5s
# [CV 1/3; 10/30] START boosting_type=goss, colsample_bytree=1.0, importance_type=gain, learning_rate=0.2, max_depth=15, min_child_samples=10, min_child_weight=1, min_split_gain=0.1, n_estimators=100, num_leaves=20, reg_alpha=0.01, reg_lambda=0.5, subsample=0.9, subsample_freq=5
# [CV 1/3; 10/30] END boosting_type=goss, colsample_bytree=1.0, importance_type=gain, learning_rate=0.2, max_depth=15, min_child_samples=10, min_child_weight=1, min_split_gain=0.1, n_estimators=100, num_leaves=20, reg_alpha=0.01, reg_lambda=0.5, subsample=0.9, subsample_freq=5;, score=(train=nan, test=nan) total time=  11.1s
# [CV 2/3; 10/30] START boosting_type=goss, colsample_bytree=1.0, importance_type=gain, learning_rate=0.2, max_depth=15, min_child_samples=10, min_child_weight=1, min_split_gain=0.1, n_estimators=100, num_leaves=20, reg_alpha=0.01, reg_lambda=0.5, subsample=0.9, subsample_freq=5
# [CV 2/3; 10/30] END boosting_type=goss, colsample_bytree=1.0, importance_type=gain, learning_rate=0.2, max_depth=15, min_child_samples=10, min_child_weight=1, min_split_gain=0.1, n_estimators=100, num_leaves=20, reg_alpha=0.01, reg_lambda=0.5, subsample=0.9, subsample_freq=5;, score=(train=nan, test=nan) total time=  10.5s
# [CV 3/3; 10/30] START boosting_type=goss, colsample_bytree=1.0, importance_type=gain, learning_rate=0.2, max_depth=15, min_child_samples=10, min_child_weight=1, min_split_gain=0.1, n_estimators=100, num_leaves=20, reg_alpha=0.01, reg_lambda=0.5, subsample=0.9, subsample_freq=5
# [CV 3/3; 10/30] END boosting_type=goss, colsample_bytree=1.0, importance_type=gain, learning_rate=0.2, max_depth=15, min_child_samples=10, min_child_weight=1, min_split_gain=0.1, n_estimators=100, num_leaves=20, reg_alpha=0.01, reg_lambda=0.5, subsample=0.9, subsample_freq=5;, score=(train=nan, test=nan) total time=  10.4s
# [CV 1/3; 11/30] START boosting_type=dart, colsample_bytree=0.7, importance_type=split, learning_rate=0.5, max_depth=10, min_child_samples=40, min_child_weight=0.001, min_split_gain=0.01, n_estimators=400, num_leaves=40, reg_alpha=0.01, reg_lambda=0.5, subsample=0.9, subsample_freq=10
# [CV 1/3; 11/30] END boosting_type=dart, colsample_bytree=0.7, importance_type=split, learning_rate=0.5, max_depth=10, min_child_samples=40, min_child_weight=0.001, min_split_gain=0.01, n_estimators=400, num_leaves=40, reg_alpha=0.01, reg_lambda=0.5, subsample=0.9, subsample_freq=10;, score=(train=0.980, test=0.744) total time= 2.9min
# [CV 2/3; 11/30] START boosting_type=dart, colsample_bytree=0.7, importance_type=split, learning_rate=0.5, max_depth=10, min_child_samples=40, min_child_weight=0.001, min_split_gain=0.01, n_estimators=400, num_leaves=40, reg_alpha=0.01, reg_lambda=0.5, subsample=0.9, subsample_freq=10
# [CV 2/3; 11/30] END boosting_type=dart, colsample_bytree=0.7, importance_type=split, learning_rate=0.5, max_depth=10, min_child_samples=40, min_child_weight=0.001, min_split_gain=0.01, n_estimators=400, num_leaves=40, reg_alpha=0.01, reg_lambda=0.5, subsample=0.9, subsample_freq=10;, score=(train=0.981, test=0.742) total time= 2.9min
# [CV 3/3; 11/30] START boosting_type=dart, colsample_bytree=0.7, importance_type=split, learning_rate=0.5, max_depth=10, min_child_samples=40, min_child_weight=0.001, min_split_gain=0.01, n_estimators=400, num_leaves=40, reg_alpha=0.01, reg_lambda=0.5, subsample=0.9, subsample_freq=10
# [CV 3/3; 11/30] END boosting_type=dart, colsample_bytree=0.7, importance_type=split, learning_rate=0.5, max_depth=10, min_child_samples=40, min_child_weight=0.001, min_split_gain=0.01, n_estimators=400, num_leaves=40, reg_alpha=0.01, reg_lambda=0.5, subsample=0.9, subsample_freq=10;, score=(train=0.981, test=0.745) total time= 2.9min
# [CV 1/3; 12/30] START boosting_type=dart, colsample_bytree=0.7, importance_type=gain, learning_rate=0.1, max_depth=20, min_child_samples=10, min_child_weight=0.001, min_split_gain=0.01, n_estimators=600, num_leaves=60, reg_alpha=5, reg_lambda=0.5, subsample=0.9, subsample_freq=1
# [CV 1/3; 12/30] END boosting_type=dart, colsample_bytree=0.7, importance_type=gain, learning_rate=0.1, max_depth=20, min_child_samples=10, min_child_weight=0.001, min_split_gain=0.01, n_estimators=600, num_leaves=60, reg_alpha=5, reg_lambda=0.5, subsample=0.9, subsample_freq=1;, score=(train=0.940, test=0.776) total time= 7.8min
# [CV 2/3; 12/30] START boosting_type=dart, colsample_bytree=0.7, importance_type=gain, learning_rate=0.1, max_depth=20, min_child_samples=10, min_child_weight=0.001, min_split_gain=0.01, n_estimators=600, num_leaves=60, reg_alpha=5, reg_lambda=0.5, subsample=0.9, subsample_freq=1
# [CV 2/3; 12/30] END boosting_type=dart, colsample_bytree=0.7, importance_type=gain, learning_rate=0.1, max_depth=20, min_child_samples=10, min_child_weight=0.001, min_split_gain=0.01, n_estimators=600, num_leaves=60, reg_alpha=5, reg_lambda=0.5, subsample=0.9, subsample_freq=1;, score=(train=0.940, test=0.769) total time= 7.9min
# [CV 3/3; 12/30] START boosting_type=dart, colsample_bytree=0.7, importance_type=gain, learning_rate=0.1, max_depth=20, min_child_samples=10, min_child_weight=0.001, min_split_gain=0.01, n_estimators=600, num_leaves=60, reg_alpha=5, reg_lambda=0.5, subsample=0.9, subsample_freq=1
# [CV 3/3; 12/30] END boosting_type=dart, colsample_bytree=0.7, importance_type=gain, learning_rate=0.1, max_depth=20, min_child_samples=10, min_child_weight=0.001, min_split_gain=0.01, n_estimators=600, num_leaves=60, reg_alpha=5, reg_lambda=0.5, subsample=0.9, subsample_freq=1;, score=(train=0.941, test=0.777) total time= 7.8min
# [CV 1/3; 13/30] START boosting_type=goss, colsample_bytree=1.0, importance_type=gain, learning_rate=0.1, max_depth=5, min_child_samples=30, min_child_weight=0.1, min_split_gain=0, n_estimators=300, num_leaves=31, reg_alpha=5, reg_lambda=0, subsample=0.8, subsample_freq=10
# [CV 1/3; 13/30] END boosting_type=goss, colsample_bytree=1.0, importance_type=gain, learning_rate=0.1, max_depth=5, min_child_samples=30, min_child_weight=0.1, min_split_gain=0, n_estimators=300, num_leaves=31, reg_alpha=5, reg_lambda=0, subsample=0.8, subsample_freq=10;, score=(train=nan, test=nan) total time=  10.8s
# [CV 2/3; 13/30] START boosting_type=goss, colsample_bytree=1.0, importance_type=gain, learning_rate=0.1, max_depth=5, min_child_samples=30, min_child_weight=0.1, min_split_gain=0, n_estimators=300, num_leaves=31, reg_alpha=5, reg_lambda=0, subsample=0.8, subsample_freq=10
# [CV 2/3; 13/30] END boosting_type=goss, colsample_bytree=1.0, importance_type=gain, learning_rate=0.1, max_depth=5, min_child_samples=30, min_child_weight=0.1, min_split_gain=0, n_estimators=300, num_leaves=31, reg_alpha=5, reg_lambda=0, subsample=0.8, subsample_freq=10;, score=(train=nan, test=nan) total time=  11.3s
# [CV 3/3; 13/30] START boosting_type=goss, colsample_bytree=1.0, importance_type=gain, learning_rate=0.1, max_depth=5, min_child_samples=30, min_child_weight=0.1, min_split_gain=0, n_estimators=300, num_leaves=31, reg_alpha=5, reg_lambda=0, subsample=0.8, subsample_freq=10
# [CV 3/3; 13/30] END boosting_type=goss, colsample_bytree=1.0, importance_type=gain, learning_rate=0.1, max_depth=5, min_child_samples=30, min_child_weight=0.1, min_split_gain=0, n_estimators=300, num_leaves=31, reg_alpha=5, reg_lambda=0, subsample=0.8, subsample_freq=10;, score=(train=nan, test=nan) total time=  11.6s
# [CV 1/3; 14/30] START boosting_type=gbdt, colsample_bytree=0.8, importance_type=gain, learning_rate=0.2, max_depth=5, min_child_samples=100, min_child_weight=0.1, min_split_gain=0.01, n_estimators=100, num_leaves=40, reg_alpha=1, reg_lambda=0.05, subsample=0.6, subsample_freq=0
# [CV 1/3; 14/30] END boosting_type=gbdt, colsample_bytree=0.8, importance_type=gain, learning_rate=0.2, max_depth=5, min_child_samples=100, min_child_weight=0.1, min_split_gain=0.01, n_estimators=100, num_leaves=40, reg_alpha=1, reg_lambda=0.05, subsample=0.6, subsample_freq=0;, score=(train=0.872, test=0.767) total time=  26.4s
# [CV 2/3; 14/30] START boosting_type=gbdt, colsample_bytree=0.8, importance_type=gain, learning_rate=0.2, max_depth=5, min_child_samples=100, min_child_weight=0.1, min_split_gain=0.01, n_estimators=100, num_leaves=40, reg_alpha=1, reg_lambda=0.05, subsample=0.6, subsample_freq=0
# [CV 2/3; 14/30] END boosting_type=gbdt, colsample_bytree=0.8, importance_type=gain, learning_rate=0.2, max_depth=5, min_child_samples=100, min_child_weight=0.1, min_split_gain=0.01, n_estimators=100, num_leaves=40, reg_alpha=1, reg_lambda=0.05, subsample=0.6, subsample_freq=0;, score=(train=0.874, test=0.761) total time=  25.5s
# [CV 3/3; 14/30] START boosting_type=gbdt, colsample_bytree=0.8, importance_type=gain, learning_rate=0.2, max_depth=5, min_child_samples=100, min_child_weight=0.1, min_split_gain=0.01, n_estimators=100, num_leaves=40, reg_alpha=1, reg_lambda=0.05, subsample=0.6, subsample_freq=0
# [CV 3/3; 14/30] END boosting_type=gbdt, colsample_bytree=0.8, importance_type=gain, learning_rate=0.2, max_depth=5, min_child_samples=100, min_child_weight=0.1, min_split_gain=0.01, n_estimators=100, num_leaves=40, reg_alpha=1, reg_lambda=0.05, subsample=0.6, subsample_freq=0;, score=(train=0.873, test=0.768) total time=  25.1s
# [CV 1/3; 15/30] START boosting_type=goss, colsample_bytree=0.8, importance_type=split, learning_rate=0.3, max_depth=25, min_child_samples=40, min_child_weight=0.01, min_split_gain=0, n_estimators=400, num_leaves=70, reg_alpha=0.01, reg_lambda=1, subsample=0.9, subsample_freq=1
# [CV 1/3; 15/30] END boosting_type=goss, colsample_bytree=0.8, importance_type=split, learning_rate=0.3, max_depth=25, min_child_samples=40, min_child_weight=0.01, min_split_gain=0, n_estimators=400, num_leaves=70, reg_alpha=0.01, reg_lambda=1, subsample=0.9, subsample_freq=1;, score=(train=nan, test=nan) total time=   9.5s
# [CV 2/3; 15/30] START boosting_type=goss, colsample_bytree=0.8, importance_type=split, learning_rate=0.3, max_depth=25, min_child_samples=40, min_child_weight=0.01, min_split_gain=0, n_estimators=400, num_leaves=70, reg_alpha=0.01, reg_lambda=1, subsample=0.9, subsample_freq=1
# [CV 2/3; 15/30] END boosting_type=goss, colsample_bytree=0.8, importance_type=split, learning_rate=0.3, max_depth=25, min_child_samples=40, min_child_weight=0.01, min_split_gain=0, n_estimators=400, num_leaves=70, reg_alpha=0.01, reg_lambda=1, subsample=0.9, subsample_freq=1;, score=(train=nan, test=nan) total time=  10.8s
# [CV 3/3; 15/30] START boosting_type=goss, colsample_bytree=0.8, importance_type=split, learning_rate=0.3, max_depth=25, min_child_samples=40, min_child_weight=0.01, min_split_gain=0, n_estimators=400, num_leaves=70, reg_alpha=0.01, reg_lambda=1, subsample=0.9, subsample_freq=1
# [CV 3/3; 15/30] END boosting_type=goss, colsample_bytree=0.8, importance_type=split, learning_rate=0.3, max_depth=25, min_child_samples=40, min_child_weight=0.01, min_split_gain=0, n_estimators=400, num_leaves=70, reg_alpha=0.01, reg_lambda=1, subsample=0.9, subsample_freq=1;, score=(train=nan, test=nan) total time=  11.2s
# [CV 1/3; 16/30] START boosting_type=dart, colsample_bytree=0.9, importance_type=gain, learning_rate=0.01, max_depth=10, min_child_samples=100, min_child_weight=0.01, min_split_gain=0, n_estimators=500, num_leaves=80, reg_alpha=0.1, reg_lambda=0.01, subsample=0.7, subsample_freq=1
# [CV 1/3; 16/30] END boosting_type=dart, colsample_bytree=0.9, importance_type=gain, learning_rate=0.01, max_depth=10, min_child_samples=100, min_child_weight=0.01, min_split_gain=0, n_estimators=500, num_leaves=80, reg_alpha=0.1, reg_lambda=0.01, subsample=0.7, subsample_freq=1;, score=(train=0.813, test=0.756) total time= 6.8min
# [CV 2/3; 16/30] START boosting_type=dart, colsample_bytree=0.9, importance_type=gain, learning_rate=0.01, max_depth=10, min_child_samples=100, min_child_weight=0.01, min_split_gain=0, n_estimators=500, num_leaves=80, reg_alpha=0.1, reg_lambda=0.01, subsample=0.7, subsample_freq=1
# [CV 2/3; 16/30] END boosting_type=dart, colsample_bytree=0.9, importance_type=gain, learning_rate=0.01, max_depth=10, min_child_samples=100, min_child_weight=0.01, min_split_gain=0, n_estimators=500, num_leaves=80, reg_alpha=0.1, reg_lambda=0.01, subsample=0.7, subsample_freq=1;, score=(train=0.815, test=0.746) total time= 6.9min
# [CV 3/3; 16/30] START boosting_type=dart, colsample_bytree=0.9, importance_type=gain, learning_rate=0.01, max_depth=10, min_child_samples=100, min_child_weight=0.01, min_split_gain=0, n_estimators=500, num_leaves=80, reg_alpha=0.1, reg_lambda=0.01, subsample=0.7, subsample_freq=1
# [CV 3/3; 16/30] END boosting_type=dart, colsample_bytree=0.9, importance_type=gain, learning_rate=0.01, max_depth=10, min_child_samples=100, min_child_weight=0.01, min_split_gain=0, n_estimators=500, num_leaves=80, reg_alpha=0.1, reg_lambda=0.01, subsample=0.7, subsample_freq=1;, score=(train=0.813, test=0.757) total time= 6.9min
# [CV 1/3; 17/30] START boosting_type=gbdt, colsample_bytree=0.6, importance_type=split, learning_rate=0.05, max_depth=5, min_child_samples=10, min_child_weight=0.01, min_split_gain=0.01, n_estimators=300, num_leaves=70, reg_alpha=2, reg_lambda=5, subsample=0.9, subsample_freq=1
# [CV 1/3; 17/30] END boosting_type=gbdt, colsample_bytree=0.6, importance_type=split, learning_rate=0.05, max_depth=5, min_child_samples=10, min_child_weight=0.01, min_split_gain=0.01, n_estimators=300, num_leaves=70, reg_alpha=2, reg_lambda=5, subsample=0.9, subsample_freq=1;, score=(train=0.863, test=0.775) total time=  57.9s
# [CV 2/3; 17/30] START boosting_type=gbdt, colsample_bytree=0.6, importance_type=split, learning_rate=0.05, max_depth=5, min_child_samples=10, min_child_weight=0.01, min_split_gain=0.01, n_estimators=300, num_leaves=70, reg_alpha=2, reg_lambda=5, subsample=0.9, subsample_freq=1
# [CV 2/3; 17/30] END boosting_type=gbdt, colsample_bytree=0.6, importance_type=split, learning_rate=0.05, max_depth=5, min_child_samples=10, min_child_weight=0.01, min_split_gain=0.01, n_estimators=300, num_leaves=70, reg_alpha=2, reg_lambda=5, subsample=0.9, subsample_freq=1;, score=(train=0.864, test=0.769) total time=  58.8s
# [CV 3/3; 17/30] START boosting_type=gbdt, colsample_bytree=0.6, importance_type=split, learning_rate=0.05, max_depth=5, min_child_samples=10, min_child_weight=0.01, min_split_gain=0.01, n_estimators=300, num_leaves=70, reg_alpha=2, reg_lambda=5, subsample=0.9, subsample_freq=1
# [CV 3/3; 17/30] END boosting_type=gbdt, colsample_bytree=0.6, importance_type=split, learning_rate=0.05, max_depth=5, min_child_samples=10, min_child_weight=0.01, min_split_gain=0.01, n_estimators=300, num_leaves=70, reg_alpha=2, reg_lambda=5, subsample=0.9, subsample_freq=1;, score=(train=0.863, test=0.776) total time= 1.0min
# [CV 1/3; 18/30] START boosting_type=gbdt, colsample_bytree=0.7, importance_type=split, learning_rate=0.5, max_depth=-1, min_child_samples=30, min_child_weight=1, min_split_gain=0.001, n_estimators=500, num_leaves=60, reg_alpha=0, reg_lambda=2, subsample=0.8, subsample_freq=1
# [CV 1/3; 18/30] END boosting_type=gbdt, colsample_bytree=0.7, importance_type=split, learning_rate=0.5, max_depth=-1, min_child_samples=30, min_child_weight=1, min_split_gain=0.001, n_estimators=500, num_leaves=60, reg_alpha=0, reg_lambda=2, subsample=0.8, subsample_freq=1;, score=(train=1.000, test=0.708) total time= 2.1min
# [CV 2/3; 18/30] START boosting_type=gbdt, colsample_bytree=0.7, importance_type=split, learning_rate=0.5, max_depth=-1, min_child_samples=30, min_child_weight=1, min_split_gain=0.001, n_estimators=500, num_leaves=60, reg_alpha=0, reg_lambda=2, subsample=0.8, subsample_freq=1
# [CV 2/3; 18/30] END boosting_type=gbdt, colsample_bytree=0.7, importance_type=split, learning_rate=0.5, max_depth=-1, min_child_samples=30, min_child_weight=1, min_split_gain=0.001, n_estimators=500, num_leaves=60, reg_alpha=0, reg_lambda=2, subsample=0.8, subsample_freq=1;, score=(train=1.000, test=0.705) total time= 2.1min
# [CV 3/3; 18/30] START boosting_type=gbdt, colsample_bytree=0.7, importance_type=split, learning_rate=0.5, max_depth=-1, min_child_samples=30, min_child_weight=1, min_split_gain=0.001, n_estimators=500, num_leaves=60, reg_alpha=0, reg_lambda=2, subsample=0.8, subsample_freq=1
# [CV 3/3; 18/30] END boosting_type=gbdt, colsample_bytree=0.7, importance_type=split, learning_rate=0.5, max_depth=-1, min_child_samples=30, min_child_weight=1, min_split_gain=0.001, n_estimators=500, num_leaves=60, reg_alpha=0, reg_lambda=2, subsample=0.8, subsample_freq=1;, score=(train=1.000, test=0.711) total time= 2.1min
# [CV 1/3; 19/30] START boosting_type=dart, colsample_bytree=0.6, importance_type=split, learning_rate=0.05, max_depth=15, min_child_samples=50, min_child_weight=1, min_split_gain=0, n_estimators=600, num_leaves=70, reg_alpha=0.01, reg_lambda=1, subsample=0.6, subsample_freq=10
# [CV 1/3; 19/30] END boosting_type=dart, colsample_bytree=0.6, importance_type=split, learning_rate=0.05, max_depth=15, min_child_samples=50, min_child_weight=1, min_split_gain=0, n_estimators=600, num_leaves=70, reg_alpha=0.01, reg_lambda=1, subsample=0.6, subsample_freq=10;, score=(train=0.901, test=0.773) total time= 7.9min
# [CV 2/3; 19/30] START boosting_type=dart, colsample_bytree=0.6, importance_type=split, learning_rate=0.05, max_depth=15, min_child_samples=50, min_child_weight=1, min_split_gain=0, n_estimators=600, num_leaves=70, reg_alpha=0.01, reg_lambda=1, subsample=0.6, subsample_freq=10
# [CV 2/3; 19/30] END boosting_type=dart, colsample_bytree=0.6, importance_type=split, learning_rate=0.05, max_depth=15, min_child_samples=50, min_child_weight=1, min_split_gain=0, n_estimators=600, num_leaves=70, reg_alpha=0.01, reg_lambda=1, subsample=0.6, subsample_freq=10;, score=(train=0.901, test=0.766) total time= 7.9min
# [CV 3/3; 19/30] START boosting_type=dart, colsample_bytree=0.6, importance_type=split, learning_rate=0.05, max_depth=15, min_child_samples=50, min_child_weight=1, min_split_gain=0, n_estimators=600, num_leaves=70, reg_alpha=0.01, reg_lambda=1, subsample=0.6, subsample_freq=10
# [CV 3/3; 19/30] END boosting_type=dart, colsample_bytree=0.6, importance_type=split, learning_rate=0.05, max_depth=15, min_child_samples=50, min_child_weight=1, min_split_gain=0, n_estimators=600, num_leaves=70, reg_alpha=0.01, reg_lambda=1, subsample=0.6, subsample_freq=10;, score=(train=0.900, test=0.775) total time= 7.8min
# [CV 1/3; 20/30] START boosting_type=goss, colsample_bytree=0.9, importance_type=split, learning_rate=0.3, max_depth=20, min_child_samples=40, min_child_weight=0.1, min_split_gain=0.1, n_estimators=500, num_leaves=20, reg_alpha=1, reg_lambda=0, subsample=0.6, subsample_freq=5
# [CV 1/3; 20/30] END boosting_type=goss, colsample_bytree=0.9, importance_type=split, learning_rate=0.3, max_depth=20, min_child_samples=40, min_child_weight=0.1, min_split_gain=0.1, n_estimators=500, num_leaves=20, reg_alpha=1, reg_lambda=0, subsample=0.6, subsample_freq=5;, score=(train=nan, test=nan) total time=  11.1s
# [CV 2/3; 20/30] START boosting_type=goss, colsample_bytree=0.9, importance_type=split, learning_rate=0.3, max_depth=20, min_child_samples=40, min_child_weight=0.1, min_split_gain=0.1, n_estimators=500, num_leaves=20, reg_alpha=1, reg_lambda=0, subsample=0.6, subsample_freq=5
# [CV 2/3; 20/30] END boosting_type=goss, colsample_bytree=0.9, importance_type=split, learning_rate=0.3, max_depth=20, min_child_samples=40, min_child_weight=0.1, min_split_gain=0.1, n_estimators=500, num_leaves=20, reg_alpha=1, reg_lambda=0, subsample=0.6, subsample_freq=5;, score=(train=nan, test=nan) total time=   9.9s
# [CV 3/3; 20/30] START boosting_type=goss, colsample_bytree=0.9, importance_type=split, learning_rate=0.3, max_depth=20, min_child_samples=40, min_child_weight=0.1, min_split_gain=0.1, n_estimators=500, num_leaves=20, reg_alpha=1, reg_lambda=0, subsample=0.6, subsample_freq=5
# [CV 3/3; 20/30] END boosting_type=goss, colsample_bytree=0.9, importance_type=split, learning_rate=0.3, max_depth=20, min_child_samples=40, min_child_weight=0.1, min_split_gain=0.1, n_estimators=500, num_leaves=20, reg_alpha=1, reg_lambda=0, subsample=0.6, subsample_freq=5;, score=(train=nan, test=nan) total time=  10.8s
# [CV 1/3; 21/30] START boosting_type=dart, colsample_bytree=0.9, importance_type=gain, learning_rate=0.01, max_depth=25, min_child_samples=30, min_child_weight=0.01, min_split_gain=0.001, n_estimators=200, num_leaves=150, reg_alpha=2, reg_lambda=5, subsample=0.7, subsample_freq=0
# [CV 1/3; 21/30] END boosting_type=dart, colsample_bytree=0.9, importance_type=gain, learning_rate=0.01, max_depth=25, min_child_samples=30, min_child_weight=0.01, min_split_gain=0.001, n_estimators=200, num_leaves=150, reg_alpha=2, reg_lambda=5, subsample=0.7, subsample_freq=0;, score=(train=0.824, test=0.748) total time= 3.4min
# [CV 2/3; 21/30] START boosting_type=dart, colsample_bytree=0.9, importance_type=gain, learning_rate=0.01, max_depth=25, min_child_samples=30, min_child_weight=0.01, min_split_gain=0.001, n_estimators=200, num_leaves=150, reg_alpha=2, reg_lambda=5, subsample=0.7, subsample_freq=0
# [CV 2/3; 21/30] END boosting_type=dart, colsample_bytree=0.9, importance_type=gain, learning_rate=0.01, max_depth=25, min_child_samples=30, min_child_weight=0.01, min_split_gain=0.001, n_estimators=200, num_leaves=150, reg_alpha=2, reg_lambda=5, subsample=0.7, subsample_freq=0;, score=(train=0.827, test=0.737) total time= 3.4min
# [CV 3/3; 21/30] START boosting_type=dart, colsample_bytree=0.9, importance_type=gain, learning_rate=0.01, max_depth=25, min_child_samples=30, min_child_weight=0.01, min_split_gain=0.001, n_estimators=200, num_leaves=150, reg_alpha=2, reg_lambda=5, subsample=0.7, subsample_freq=0
# [CV 3/3; 21/30] END boosting_type=dart, colsample_bytree=0.9, importance_type=gain, learning_rate=0.01, max_depth=25, min_child_samples=30, min_child_weight=0.01, min_split_gain=0.001, n_estimators=200, num_leaves=150, reg_alpha=2, reg_lambda=5, subsample=0.7, subsample_freq=0;, score=(train=0.823, test=0.746) total time= 3.4min
# [CV 1/3; 22/30] START boosting_type=dart, colsample_bytree=0.9, importance_type=gain, learning_rate=0.2, max_depth=10, min_child_samples=40, min_child_weight=0.001, min_split_gain=0.001, n_estimators=200, num_leaves=70, reg_alpha=0.5, reg_lambda=2, subsample=0.7, subsample_freq=1
# [CV 1/3; 22/30] END boosting_type=dart, colsample_bytree=0.9, importance_type=gain, learning_rate=0.2, max_depth=10, min_child_samples=40, min_child_weight=0.001, min_split_gain=0.001, n_estimators=200, num_leaves=70, reg_alpha=0.5, reg_lambda=2, subsample=0.7, subsample_freq=1;, score=(train=0.927, test=0.768) total time= 2.0min
# [CV 2/3; 22/30] START boosting_type=dart, colsample_bytree=0.9, importance_type=gain, learning_rate=0.2, max_depth=10, min_child_samples=40, min_child_weight=0.001, min_split_gain=0.001, n_estimators=200, num_leaves=70, reg_alpha=0.5, reg_lambda=2, subsample=0.7, subsample_freq=1
# [CV 2/3; 22/30] END boosting_type=dart, colsample_bytree=0.9, importance_type=gain, learning_rate=0.2, max_depth=10, min_child_samples=40, min_child_weight=0.001, min_split_gain=0.001, n_estimators=200, num_leaves=70, reg_alpha=0.5, reg_lambda=2, subsample=0.7, subsample_freq=1;, score=(train=0.928, test=0.762) total time= 1.9min
# [CV 3/3; 22/30] START boosting_type=dart, colsample_bytree=0.9, importance_type=gain, learning_rate=0.2, max_depth=10, min_child_samples=40, min_child_weight=0.001, min_split_gain=0.001, n_estimators=200, num_leaves=70, reg_alpha=0.5, reg_lambda=2, subsample=0.7, subsample_freq=1
# [CV 3/3; 22/30] END boosting_type=dart, colsample_bytree=0.9, importance_type=gain, learning_rate=0.2, max_depth=10, min_child_samples=40, min_child_weight=0.001, min_split_gain=0.001, n_estimators=200, num_leaves=70, reg_alpha=0.5, reg_lambda=2, subsample=0.7, subsample_freq=1;, score=(train=0.927, test=0.768) total time= 2.0min
# [CV 1/3; 23/30] START boosting_type=dart, colsample_bytree=0.8, importance_type=split, learning_rate=0.5, max_depth=10, min_child_samples=10, min_child_weight=1, min_split_gain=0, n_estimators=200, num_leaves=40, reg_alpha=1, reg_lambda=0.01, subsample=0.6, subsample_freq=1
# [CV 1/3; 23/30] END boosting_type=dart, colsample_bytree=0.8, importance_type=split, learning_rate=0.5, max_depth=10, min_child_samples=10, min_child_weight=1, min_split_gain=0, n_estimators=200, num_leaves=40, reg_alpha=1, reg_lambda=0.01, subsample=0.6, subsample_freq=1;, score=(train=0.932, test=0.747) total time= 1.4min
# [CV 2/3; 23/30] START boosting_type=dart, colsample_bytree=0.8, importance_type=split, learning_rate=0.5, max_depth=10, min_child_samples=10, min_child_weight=1, min_split_gain=0, n_estimators=200, num_leaves=40, reg_alpha=1, reg_lambda=0.01, subsample=0.6, subsample_freq=1
# [CV 2/3; 23/30] END boosting_type=dart, colsample_bytree=0.8, importance_type=split, learning_rate=0.5, max_depth=10, min_child_samples=10, min_child_weight=1, min_split_gain=0, n_estimators=200, num_leaves=40, reg_alpha=1, reg_lambda=0.01, subsample=0.6, subsample_freq=1;, score=(train=0.933, test=0.738) total time= 1.4min
# [CV 3/3; 23/30] START boosting_type=dart, colsample_bytree=0.8, importance_type=split, learning_rate=0.5, max_depth=10, min_child_samples=10, min_child_weight=1, min_split_gain=0, n_estimators=200, num_leaves=40, reg_alpha=1, reg_lambda=0.01, subsample=0.6, subsample_freq=1
# [CV 3/3; 23/30] END boosting_type=dart, colsample_bytree=0.8, importance_type=split, learning_rate=0.5, max_depth=10, min_child_samples=10, min_child_weight=1, min_split_gain=0, n_estimators=200, num_leaves=40, reg_alpha=1, reg_lambda=0.01, subsample=0.6, subsample_freq=1;, score=(train=0.932, test=0.747) total time= 1.4min
# [CV 1/3; 24/30] START boosting_type=dart, colsample_bytree=1.0, importance_type=gain, learning_rate=0.05, max_depth=25, min_child_samples=50, min_child_weight=1, min_split_gain=0.001, n_estimators=300, num_leaves=20, reg_alpha=0.1, reg_lambda=0.01, subsample=0.9, subsample_freq=10
# [CV 1/3; 24/30] END boosting_type=dart, colsample_bytree=1.0, importance_type=gain, learning_rate=0.05, max_depth=25, min_child_samples=50, min_child_weight=1, min_split_gain=0.001, n_estimators=300, num_leaves=20, reg_alpha=0.1, reg_lambda=0.01, subsample=0.9, subsample_freq=10;, score=(train=0.791, test=0.763) total time= 2.1min
# [CV 2/3; 24/30] START boosting_type=dart, colsample_bytree=1.0, importance_type=gain, learning_rate=0.05, max_depth=25, min_child_samples=50, min_child_weight=1, min_split_gain=0.001, n_estimators=300, num_leaves=20, reg_alpha=0.1, reg_lambda=0.01, subsample=0.9, subsample_freq=10
# [CV 2/3; 24/30] END boosting_type=dart, colsample_bytree=1.0, importance_type=gain, learning_rate=0.05, max_depth=25, min_child_samples=50, min_child_weight=1, min_split_gain=0.001, n_estimators=300, num_leaves=20, reg_alpha=0.1, reg_lambda=0.01, subsample=0.9, subsample_freq=10;, score=(train=0.793, test=0.754) total time= 2.1min
# [CV 3/3; 24/30] START boosting_type=dart, colsample_bytree=1.0, importance_type=gain, learning_rate=0.05, max_depth=25, min_child_samples=50, min_child_weight=1, min_split_gain=0.001, n_estimators=300, num_leaves=20, reg_alpha=0.1, reg_lambda=0.01, subsample=0.9, subsample_freq=10
# [CV 3/3; 24/30] END boosting_type=dart, colsample_bytree=1.0, importance_type=gain, learning_rate=0.05, max_depth=25, min_child_samples=50, min_child_weight=1, min_split_gain=0.001, n_estimators=300, num_leaves=20, reg_alpha=0.1, reg_lambda=0.01, subsample=0.9, subsample_freq=10;, score=(train=0.791, test=0.763) total time= 2.2min
# [CV 1/3; 25/30] START boosting_type=dart, colsample_bytree=0.7, importance_type=split, learning_rate=0.3, max_depth=5, min_child_samples=50, min_child_weight=0.01, min_split_gain=0, n_estimators=600, num_leaves=60, reg_alpha=0.01, reg_lambda=0.1, subsample=0.6, subsample_freq=0
# [CV 1/3; 25/30] END boosting_type=dart, colsample_bytree=0.7, importance_type=split, learning_rate=0.3, max_depth=5, min_child_samples=50, min_child_weight=0.01, min_split_gain=0, n_estimators=600, num_leaves=60, reg_alpha=0.01, reg_lambda=0.1, subsample=0.6, subsample_freq=0;, score=(train=0.937, test=0.763) total time= 4.1min
# [CV 2/3; 25/30] START boosting_type=dart, colsample_bytree=0.7, importance_type=split, learning_rate=0.3, max_depth=5, min_child_samples=50, min_child_weight=0.01, min_split_gain=0, n_estimators=600, num_leaves=60, reg_alpha=0.01, reg_lambda=0.1, subsample=0.6, subsample_freq=0
# [CV 2/3; 25/30] END boosting_type=dart, colsample_bytree=0.7, importance_type=split, learning_rate=0.3, max_depth=5, min_child_samples=50, min_child_weight=0.01, min_split_gain=0, n_estimators=600, num_leaves=60, reg_alpha=0.01, reg_lambda=0.1, subsample=0.6, subsample_freq=0;, score=(train=0.940, test=0.758) total time= 4.2min
# [CV 3/3; 25/30] START boosting_type=dart, colsample_bytree=0.7, importance_type=split, learning_rate=0.3, max_depth=5, min_child_samples=50, min_child_weight=0.01, min_split_gain=0, n_estimators=600, num_leaves=60, reg_alpha=0.01, reg_lambda=0.1, subsample=0.6, subsample_freq=0
# [CV 3/3; 25/30] END boosting_type=dart, colsample_bytree=0.7, importance_type=split, learning_rate=0.3, max_depth=5, min_child_samples=50, min_child_weight=0.01, min_split_gain=0, n_estimators=600, num_leaves=60, reg_alpha=0.01, reg_lambda=0.1, subsample=0.6, subsample_freq=0;, score=(train=0.940, test=0.764) total time= 4.1min
# [CV 1/3; 26/30] START boosting_type=dart, colsample_bytree=0.9, importance_type=gain, learning_rate=0.5, max_depth=5, min_child_samples=30, min_child_weight=0.1, min_split_gain=0.1, n_estimators=300, num_leaves=60, reg_alpha=1, reg_lambda=0, subsample=0.8, subsample_freq=10
# [CV 1/3; 26/30] END boosting_type=dart, colsample_bytree=0.9, importance_type=gain, learning_rate=0.5, max_depth=5, min_child_samples=30, min_child_weight=0.1, min_split_gain=0.1, n_estimators=300, num_leaves=60, reg_alpha=1, reg_lambda=0, subsample=0.8, subsample_freq=10;, score=(train=0.922, test=0.751) total time= 1.7min
# [CV 2/3; 26/30] START boosting_type=dart, colsample_bytree=0.9, importance_type=gain, learning_rate=0.5, max_depth=5, min_child_samples=30, min_child_weight=0.1, min_split_gain=0.1, n_estimators=300, num_leaves=60, reg_alpha=1, reg_lambda=0, subsample=0.8, subsample_freq=10
# [CV 2/3; 26/30] END boosting_type=dart, colsample_bytree=0.9, importance_type=gain, learning_rate=0.5, max_depth=5, min_child_samples=30, min_child_weight=0.1, min_split_gain=0.1, n_estimators=300, num_leaves=60, reg_alpha=1, reg_lambda=0, subsample=0.8, subsample_freq=10;, score=(train=0.927, test=0.745) total time= 1.7min
# [CV 3/3; 26/30] START boosting_type=dart, colsample_bytree=0.9, importance_type=gain, learning_rate=0.5, max_depth=5, min_child_samples=30, min_child_weight=0.1, min_split_gain=0.1, n_estimators=300, num_leaves=60, reg_alpha=1, reg_lambda=0, subsample=0.8, subsample_freq=10
# [CV 3/3; 26/30] END boosting_type=dart, colsample_bytree=0.9, importance_type=gain, learning_rate=0.5, max_depth=5, min_child_samples=30, min_child_weight=0.1, min_split_gain=0.1, n_estimators=300, num_leaves=60, reg_alpha=1, reg_lambda=0, subsample=0.8, subsample_freq=10;, score=(train=0.922, test=0.754) total time= 1.7min
# [CV 1/3; 27/30] START boosting_type=dart, colsample_bytree=0.9, importance_type=gain, learning_rate=0.05, max_depth=5, min_child_samples=20, min_child_weight=0.001, min_split_gain=0.1, n_estimators=100, num_leaves=80, reg_alpha=0.05, reg_lambda=2, subsample=1.0, subsample_freq=1
# [CV 1/3; 27/30] END boosting_type=dart, colsample_bytree=0.9, importance_type=gain, learning_rate=0.05, max_depth=5, min_child_samples=20, min_child_weight=0.001, min_split_gain=0.1, n_estimators=100, num_leaves=80, reg_alpha=0.05, reg_lambda=2, subsample=1.0, subsample_freq=1;, score=(train=0.774, test=0.749) total time=  38.9s
# [CV 2/3; 27/30] START boosting_type=dart, colsample_bytree=0.9, importance_type=gain, learning_rate=0.05, max_depth=5, min_child_samples=20, min_child_weight=0.001, min_split_gain=0.1, n_estimators=100, num_leaves=80, reg_alpha=0.05, reg_lambda=2, subsample=1.0, subsample_freq=1
# [CV 2/3; 27/30] END boosting_type=dart, colsample_bytree=0.9, importance_type=gain, learning_rate=0.05, max_depth=5, min_child_samples=20, min_child_weight=0.001, min_split_gain=0.1, n_estimators=100, num_leaves=80, reg_alpha=0.05, reg_lambda=2, subsample=1.0, subsample_freq=1;, score=(train=0.777, test=0.737) total time=  38.8s
# [CV 3/3; 27/30] START boosting_type=dart, colsample_bytree=0.9, importance_type=gain, learning_rate=0.05, max_depth=5, min_child_samples=20, min_child_weight=0.001, min_split_gain=0.1, n_estimators=100, num_leaves=80, reg_alpha=0.05, reg_lambda=2, subsample=1.0, subsample_freq=1
# [CV 3/3; 27/30] END boosting_type=dart, colsample_bytree=0.9, importance_type=gain, learning_rate=0.05, max_depth=5, min_child_samples=20, min_child_weight=0.001, min_split_gain=0.1, n_estimators=100, num_leaves=80, reg_alpha=0.05, reg_lambda=2, subsample=1.0, subsample_freq=1;, score=(train=0.773, test=0.748) total time=  37.8s
# [CV 1/3; 28/30] START boosting_type=goss, colsample_bytree=0.7, importance_type=gain, learning_rate=0.3, max_depth=15, min_child_samples=10, min_child_weight=0.1, min_split_gain=0.1, n_estimators=600, num_leaves=60, reg_alpha=0.1, reg_lambda=0, subsample=0.6, subsample_freq=10
# [CV 1/3; 28/30] END boosting_type=goss, colsample_bytree=0.7, importance_type=gain, learning_rate=0.3, max_depth=15, min_child_samples=10, min_child_weight=0.1, min_split_gain=0.1, n_estimators=600, num_leaves=60, reg_alpha=0.1, reg_lambda=0, subsample=0.6, subsample_freq=10;, score=(train=nan, test=nan) total time=  10.1s
# [CV 2/3; 28/30] START boosting_type=goss, colsample_bytree=0.7, importance_type=gain, learning_rate=0.3, max_depth=15, min_child_samples=10, min_child_weight=0.1, min_split_gain=0.1, n_estimators=600, num_leaves=60, reg_alpha=0.1, reg_lambda=0, subsample=0.6, subsample_freq=10
# [CV 2/3; 28/30] END boosting_type=goss, colsample_bytree=0.7, importance_type=gain, learning_rate=0.3, max_depth=15, min_child_samples=10, min_child_weight=0.1, min_split_gain=0.1, n_estimators=600, num_leaves=60, reg_alpha=0.1, reg_lambda=0, subsample=0.6, subsample_freq=10;, score=(train=nan, test=nan) total time=  11.0s
# [CV 3/3; 28/30] START boosting_type=goss, colsample_bytree=0.7, importance_type=gain, learning_rate=0.3, max_depth=15, min_child_samples=10, min_child_weight=0.1, min_split_gain=0.1, n_estimators=600, num_leaves=60, reg_alpha=0.1, reg_lambda=0, subsample=0.6, subsample_freq=10
# [CV 3/3; 28/30] END boosting_type=goss, colsample_bytree=0.7, importance_type=gain, learning_rate=0.3, max_depth=15, min_child_samples=10, min_child_weight=0.1, min_split_gain=0.1, n_estimators=600, num_leaves=60, reg_alpha=0.1, reg_lambda=0, subsample=0.6, subsample_freq=10;, score=(train=nan, test=nan) total time=  11.6s
# [CV 1/3; 29/30] START boosting_type=goss, colsample_bytree=0.6, importance_type=gain, learning_rate=0.05, max_depth=20, min_child_samples=40, min_child_weight=1, min_split_gain=0, n_estimators=200, num_leaves=80, reg_alpha=0, reg_lambda=0.5, subsample=0.9, subsample_freq=5
# [CV 1/3; 29/30] END boosting_type=goss, colsample_bytree=0.6, importance_type=gain, learning_rate=0.05, max_depth=20, min_child_samples=40, min_child_weight=1, min_split_gain=0, n_estimators=200, num_leaves=80, reg_alpha=0, reg_lambda=0.5, subsample=0.9, subsample_freq=5;, score=(train=nan, test=nan) total time=  11.4s
# [CV 2/3; 29/30] START boosting_type=goss, colsample_bytree=0.6, importance_type=gain, learning_rate=0.05, max_depth=20, min_child_samples=40, min_child_weight=1, min_split_gain=0, n_estimators=200, num_leaves=80, reg_alpha=0, reg_lambda=0.5, subsample=0.9, subsample_freq=5
# [CV 2/3; 29/30] END boosting_type=goss, colsample_bytree=0.6, importance_type=gain, learning_rate=0.05, max_depth=20, min_child_samples=40, min_child_weight=1, min_split_gain=0, n_estimators=200, num_leaves=80, reg_alpha=0, reg_lambda=0.5, subsample=0.9, subsample_freq=5;, score=(train=nan, test=nan) total time=  10.8s
# [CV 3/3; 29/30] START boosting_type=goss, colsample_bytree=0.6, importance_type=gain, learning_rate=0.05, max_depth=20, min_child_samples=40, min_child_weight=1, min_split_gain=0, n_estimators=200, num_leaves=80, reg_alpha=0, reg_lambda=0.5, subsample=0.9, subsample_freq=5
# [CV 3/3; 29/30] END boosting_type=goss, colsample_bytree=0.6, importance_type=gain, learning_rate=0.05, max_depth=20, min_child_samples=40, min_child_weight=1, min_split_gain=0, n_estimators=200, num_leaves=80, reg_alpha=0, reg_lambda=0.5, subsample=0.9, subsample_freq=5;, score=(train=nan, test=nan) total time=  10.4s
# [CV 1/3; 30/30] START boosting_type=dart, colsample_bytree=0.6, importance_type=gain, learning_rate=0.5, max_depth=-1, min_child_samples=40, min_child_weight=0.1, min_split_gain=0, n_estimators=800, num_leaves=150, reg_alpha=0.01, reg_lambda=0.01, subsample=0.8, subsample_freq=1
# [CV 1/3; 30/30] END boosting_type=dart, colsample_bytree=0.6, importance_type=gain, learning_rate=0.5, max_depth=-1, min_child_samples=40, min_child_weight=0.1, min_split_gain=0, n_estimators=800, num_leaves=150, reg_alpha=0.01, reg_lambda=0.01, subsample=0.8, subsample_freq=1;, score=(train=1.000, test=0.725) total time=16.0min
# [CV 2/3; 30/30] START boosting_type=dart, colsample_bytree=0.6, importance_type=gain, learning_rate=0.5, max_depth=-1, min_child_samples=40, min_child_weight=0.1, min_split_gain=0, n_estimators=800, num_leaves=150, reg_alpha=0.01, reg_lambda=0.01, subsample=0.8, subsample_freq=1
# [CV 2/3; 30/30] END boosting_type=dart, colsample_bytree=0.6, importance_type=gain, learning_rate=0.5, max_depth=-1, min_child_samples=40, min_child_weight=0.1, min_split_gain=0, n_estimators=800, num_leaves=150, reg_alpha=0.01, reg_lambda=0.01, subsample=0.8, subsample_freq=1;, score=(train=1.000, test=0.721) total time=15.9min
# [CV 3/3; 30/30] START boosting_type=dart, colsample_bytree=0.6, importance_type=gain, learning_rate=0.5, max_depth=-1, min_child_samples=40, min_child_weight=0.1, min_split_gain=0, n_estimators=800, num_leaves=150, reg_alpha=0.01, reg_lambda=0.01, subsample=0.8, subsample_freq=1
# [CV 3/3; 30/30] END boosting_type=dart, colsample_bytree=0.6, importance_type=gain, learning_rate=0.5, max_depth=-1, min_child_samples=40, min_child_weight=0.1, min_split_gain=0, n_estimators=800, num_leaves=150, reg_alpha=0.01, reg_lambda=0.01, subsample=0.8, subsample_freq=1;, score=(train=1.000, test=0.728) total time=16.0min
#
# ================================================================================
# РЕЗУЛЬТАТЫ ПОИСКА ГИПЕРПАРАМЕТРОВ LIGHTGBM
# ================================================================================
# Поиск завершен за 257.7 минут
#
# Лучшие параметры:
#   subsample_freq: 1
#   subsample: 0.9
#   reg_lambda: 0.5
#   reg_alpha: 5
#   num_leaves: 60
#   n_estimators: 600
#   min_split_gain: 0.01
#   min_child_weight: 0.001
#   min_child_samples: 10
#   max_depth: 20
#   learning_rate: 0.1
#   importance_type: gain
#   colsample_bytree: 0.7
#   boosting_type: dart
#
# Лучший ROC-AUC на кросс-валидации: 0.7742
#
# Топ-5 лучших комбинаций параметров:
#
# 1. Score: 0.7742 (+/- 0.0039)
#    n_estimators=600, learning_rate=0.1, num_leaves=60
#
# 2. Score: 0.7732 (+/- 0.0030)
#    n_estimators=300, learning_rate=0.05, num_leaves=70
#
# 3. Score: 0.7714 (+/- 0.0042)
#    n_estimators=600, learning_rate=0.05, num_leaves=70
#
# 4. Score: 0.7713 (+/- 0.0040)
#    n_estimators=400, learning_rate=0.1, num_leaves=50
#
# 5. Score: 0.7708 (+/- 0.0037)
#    n_estimators=300, learning_rate=0.1, num_leaves=60
#
# ================================================================================
# СОХРАНЕНИЕ ЛУЧШИХ ПАРАМЕТРОВ ДЛЯ ЛОКАЛЬНОГО ОБУЧЕНИЯ
# ================================================================================
#
# ✅ Лучшие параметры сохранены:
#    JSON: ./models/lgb_best_params.json
#    Полные результаты: ./models/lgb_search_results.pkl
#
# Скопируй эти параметры для обучения на своём компьютере!

# %%
print("="*80)
print("БЛОК 2: ОБУЧЕНИЕ ФИНАЛЬНОЙ МОДЕЛИ LIGHTGBM С ЛУЧШИМИ ПАРАМЕТРАМИ")
print("="*80)

import json
import joblib
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score, roc_auc_score
import lightgbm as lgb

# 1. Загрузка лучших параметров
print("\n1. Загрузка лучших параметров...")
try:
    with open('./models/lgb_best_params.json', 'r') as f:
        best_params = json.load(f)
    print(f"✅ Загружено {len(best_params)} параметров")
except FileNotFoundError:
    print("❌ Файл с параметрами не найден!")
    print("Использую лучшие параметры из random_search...")
    best_params = clean_best_params  # из предыдущего кода

# 2. Создание финальной модели
print("\n2. Создание финальной модели LightGBM...")
final_lgb = lgb.LGBMClassifier(
    **best_params,
    random_state=42,
    n_jobs=-1,            # Используем все ядра
    class_weight='balanced'
)

print(f"Параметры модели:")
for key, value in list(best_params.items())[:10]:  # покажем первые 10
    print(f"  {key}: {value}")
if len(best_params) > 10:
    print(f"  ... и еще {len(best_params) - 10} параметров")

# 3. Обучение на всех тренировочных данных
print(f"\n3. Обучение на всех {len(X_train)} samples...")
print(f"   Размер данных: {X_train.shape}")
print(f"   Количество признаков: {X_train.shape[1]}")

import time
train_start = time.time()
final_lgb.fit(X_train, y_train)
train_time = time.time() - train_start

print(f"\n✅ Модель обучена за {train_time/60:.1f} минут")
print(f"   Количество деревьев: {final_lgb.n_estimators_}")
print(f"   Количество итераций: {final_lgb.n_iter_}")

# 4. Предсказания на валидационной выборке
print(f"\n4. Предсказания на валидации ({len(X_val)} samples)...")
y_val_pred = final_lgb.predict(X_val)
y_val_pred_proba = final_lgb.predict_proba(X_val)[:, 1]

# 5. Расчет метрик
print("\n5. Расчет метрик...")
accuracy = accuracy_score(y_val, y_val_pred)
f1 = f1_score(y_val, y_val_pred, average='macro')
roc_auc = roc_auc_score(y_val, y_val_pred_proba)

# Для полноты можно добавить precision и recall
from sklearn.metrics import precision_score, recall_score
precision = precision_score(y_val, y_val_pred, average='macro', zero_division=0)
recall = recall_score(y_val, y_val_pred, average='macro', zero_division=0)

# 6. Вывод результатов
print("\n" + "="*60)
print("РЕЗУЛЬТАТЫ LIGHTGBM НА ВАЛИДАЦИОННОЙ ВЫБОРКЕ")
print("="*60)

print(f"\nОсновные метрики:")
print(f"  Accuracy:   {accuracy:.4f}")
print(f"  Precision:  {precision:.4f}")
print(f"  Recall:     {recall:.4f}")
print(f"  F1 Macro:   {f1:.4f}")
print(f"  ROC-AUC:    {roc_auc:.4f}")

# 7. Classification Report
print("\n" + "-"*60)
print("Classification Report:")
print("-"*60)
print(classification_report(y_val, y_val_pred, zero_division=0))

# 8. Confusion Matrix
print("\n" + "-"*60)
print("Confusion Matrix:")
print("-"*60)
cm = confusion_matrix(y_val, y_val_pred)
print(cm)

# 9. Важность признаков
print("\n" + "="*60)
print("ВАЖНОСТЬ ПРИЗНАКОВ LIGHTGBM (TOP-30)")
print("="*60)

feature_importance = pd.DataFrame({
    'feature': X_train.columns,
    'importance': final_lgb.feature_importances_
}).sort_values('importance', ascending=False)

print(f"\nСамые важные признаки:")
print(feature_importance.head(30).to_string(index=False))

print(f"\nСтатистика важности признаков:")
print(f"  Всего признаков: {len(feature_importance)}")
print(f"  Признаков с importance > 0: {(feature_importance['importance'] > 0).sum()}")
print(f"  Максимальная importance: {feature_importance['importance'].max():.4f}")
print(f"  Минимальная importance: {feature_importance['importance'].min():.4f}")
print(f"  Средняя importance: {feature_importance['importance'].mean():.6f}")

# 10. Сохранение финальной модели и результатов
print("\n" + "="*60)
print("СОХРАНЕНИЕ ФИНАЛЬНОЙ МОДЕЛИ И РЕЗУЛЬТАТОВ")
print("="*60)

# Подготовка данных для сохранения
lgb_final_artifacts = {
    'model': final_lgb,
    'best_params': best_params,
    'cv_score': random_search.best_score_ if 'random_search' in locals() else None,
    'val_metrics': {
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1_macro': f1,
        'roc_auc': roc_auc,
        'confusion_matrix': cm.tolist()
    },
    'feature_importance': feature_importance.to_dict('records'),
    'training_info': {
        'model_type': 'LGBMClassifier',
        'training_time_minutes': train_time / 60,
        'n_estimators': final_lgb.n_estimators_,
        'n_iterations': final_lgb.n_iter_,
        'feature_count': X_train.shape[1],
        'training_samples': len(X_train),
        'validation_samples': len(X_val),
        'boosting_type': best_params.get('boosting_type', 'gbdt'),
        'timestamp': pd.Timestamp.now().strftime('%Y-%m-%d %H:%M:%S')
    }
}

# Сохраняем модель
joblib.dump(lgb_final_artifacts, './models/lgb_final_model.pkl')
print("✅ Финальная модель сохранена: './models/lgb_final_model.pkl'")


# 11. Итоговая информация
print("\n" + "="*80)
print("ИТОГОВАЯ ИНФОРМАЦИЯ О LIGHTGBM МОДЕЛИ")
print("="*80)

print(f"\nМодель: LightGBM Classifier")
if 'random_search' in locals():
    print(f"Лучший CV ROC-AUC: {random_search.best_score_:.4f}")
print(f"Валидационный ROC-AUC: {roc_auc:.4f}")
print(f"Accuracy на валидации: {accuracy:.4f}")
print(f"F1 Macro на валидации: {f1:.4f}")

print(f"\nХарактеристики модели:")
print(f"  Количество деревьев: {final_lgb.n_estimators_}")
print(f"  Тип бустинга: {best_params.get('boosting_type', 'gbdt')}")
print(f"  Learning rate: {best_params.get('learning_rate', 0.1)}")
print(f"  Количество листьев: {best_params.get('num_leaves', 31)}")
print(f"  Важных признаков (importance > 0): {(feature_importance['importance'] > 0).sum()}")

print(f"\nВремя обучения: {train_time/60:.1f} минут")

print("\n" + "="*80)
print("LIGHTGBM МОДЕЛЬ ОБУЧЕНА И ОЦЕНЕНА!")
print("="*80)
# Out:
# ================================================================================
# БЛОК 2: ОБУЧЕНИЕ ФИНАЛЬНОЙ МОДЕЛИ LIGHTGBM С ЛУЧШИМИ ПАРАМЕТРАМИ
# ================================================================================
#
# 1. Загрузка лучших параметров...
# ✅ Загружено 14 параметров
#
# 2. Создание финальной модели LightGBM...
# Параметры модели:
#   subsample_freq: 1
#   subsample: 0.9
#   reg_lambda: 0.5
#   reg_alpha: 5
#   num_leaves: 60
#   n_estimators: 600
#   min_split_gain: 0.01
#   min_child_weight: 0.001
#   min_child_samples: 10
#   max_depth: 20
#   ... и еще 4 параметров
#
# 3. Обучение на всех 184506 samples...
#    Размер данных: (184506, 697)
#    Количество признаков: 697
# [LightGBM] [Info] Number of positive: 14895, number of negative: 169611
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.206676 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 62940
# [LightGBM] [Info] Number of data points in the train set: 184506, number of used features: 668
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=-0.000000
# [LightGBM] [Info] Start training from score -0.000000
#
# ✅ Модель обучена за 1.1 минут
#    Количество деревьев: 600
#    Количество итераций: 600
#
# 4. Предсказания на валидации (61502 samples)...
#
# 5. Расчет метрик...
#
# ============================================================
# РЕЗУЛЬТАТЫ LIGHTGBM НА ВАЛИДАЦИОННОЙ ВЫБОРКЕ
# ============================================================
#
# Основные метрики:
#   Accuracy:   0.7645
#   Precision:  0.5769
#   Recall:     0.6964
#   F1 Macro:   0.5776
#   ROC-AUC:    0.7733
#
# ------------------------------------------------------------
# Classification Report:
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.96      0.78      0.86     56537
#            1       0.20      0.62      0.30      4965
#
#     accuracy                           0.76     61502
#    macro avg       0.58      0.70      0.58     61502
# weighted avg       0.90      0.76      0.81     61502
#
#
# ------------------------------------------------------------
# Confusion Matrix:
# ------------------------------------------------------------
# [[43962 12575]
#  [ 1910  3055]]
#
# ============================================================
# ВАЖНОСТЬ ПРИЗНАКОВ LIGHTGBM (TOP-30)
# ============================================================
#
# Самые важные признаки:
#                                        feature    importance
#                                   EXT_SOURCE_2 221684.804483
#                                   EXT_SOURCE_3 205518.568283
#                                  DAYS_EMPLOYED  39424.889305
#                                     DAYS_BIRTH  36465.554737
#        client_installments_AMT_PAYMENT_min_sum  35212.266060
#                                     AMT_CREDIT  32551.820084
#       client_installments_AMT_PAYMENT_min_mean  30367.106651
#                                  CODE_GENDER_F  27652.669323
#                                    AMT_ANNUITY  25503.083769
#     client_cash_CNT_INSTALMENT_FUTURE_mean_max  22154.845308
#           NAME_EDUCATION_TYPE_Higher_education  20753.096849
#                         bureau_DAYS_CREDIT_max  18280.692875
#                                DAYS_ID_PUBLISH  16380.444918
#     previous_NAME_CONTRACT_STATUS_Refused_mean  16322.792625
#                 bureau_DAYS_CREDIT_ENDDATE_max  15676.513800
#        client_installments_AMT_PAYMENT_min_max  15107.304413
#                         DAYS_LAST_PHONE_CHANGE  14598.329777
#                bureau_AMT_CREDIT_SUM_DEBT_mean  14407.361586
#                        bureau_DAYS_CREDIT_mean  14077.280331
#                              DAYS_REGISTRATION  12841.435282
#    client_cash_CNT_INSTALMENT_FUTURE_mean_mean  12238.208090
#                      previous_CNT_PAYMENT_mean  12099.989780
#               client_cash_SK_DPD_DEF_mean_mean  11488.150120
# client_installments_DAYS_ENTRY_PAYMENT_max_max  11443.794868
#        client_installments_AMT_PAYMENT_min_min  10591.620798
#          previous_HOUR_APPR_PROCESS_START_mean  10338.259203
#     client_installments_AMT_INSTALMENT_min_min  10094.854179
#             bureau_AMT_CREDIT_MAX_OVERDUE_mean   9801.638294
#                                 FLAG_OWN_CAR_N   9750.370544
#                   bureau_DAYS_ENDDATE_FACT_max   9655.207466
#
# Статистика важности признаков:
#   Всего признаков: 697
#   Признаков с importance > 0: 500
#   Максимальная importance: 221684.8045
#   Минимальная importance: 0.0000
#   Средняя importance: 2686.419215
#
# ============================================================
# СОХРАНЕНИЕ ФИНАЛЬНОЙ МОДЕЛИ И РЕЗУЛЬТАТОВ
# ============================================================
# ✅ Финальная модель сохранена: './models/lgb_final_model.pkl'
#
# ================================================================================
# ИТОГОВАЯ ИНФОРМАЦИЯ О LIGHTGBM МОДЕЛИ
# ================================================================================
#
# Модель: LightGBM Classifier
# Валидационный ROC-AUC: 0.7733
# Accuracy на валидации: 0.7645
# F1 Macro на валидации: 0.5776
#
# Характеристики модели:
#   Количество деревьев: 600
#   Тип бустинга: dart
#   Learning rate: 0.1
#   Количество листьев: 60
#   Важных признаков (importance > 0): 500
#
# Время обучения: 1.1 минут
#
# ================================================================================
# LIGHTGBM МОДЕЛЬ ОБУЧЕНА И ОЦЕНЕНА!
# ================================================================================

# %%
# 1. В начале ноутбука создаем пустой список
model_results = []

# 2. После КАЖДОЙ обученной модели:
def log_model(model, X_val, y_val, name):
    """Записывает метрики модели в таблицу"""
    
    y_pred = model.predict(X_val)
    
    result = {
        'model': name,
        'accuracy': round(accuracy_score(y_val, y_pred), 4),
        'f1': round(f1_score(y_val, y_pred, average='macro'), 4)
    }
    
    # ROC-AUC если доступен
    if hasattr(model, 'predict_proba'):
        try:
            y_proba = model.predict_proba(X_val)
            if len(model.classes_) == 2:
                result['roc_auc'] = round(roc_auc_score(y_val, y_proba[:, 1]), 4)
        except:
            pass
    
    model_results.append(result)
    
    # Создаем DataFrame и показываем
    results_df = pd.concat([pd.read_csv('results.csv'), pd.DataFrame(model_results)], ignore_index=True)
    print(f"\nДобавлена модель: {name}")
    print(results_df.to_string(index=False))
    
    return results_df

# %%
artifacts = joblib.load('./models/lgb_final_model.pkl')

results = log_model(artifacts['model'], X_val, y_val, 'LightGBM')
results.to_csv('results.csv', index=False)
# Out:
# Добавлена модель: LightGBM
#                  model  accuracy     f1  roc_auc
#          SGDClassifier    0.7016 0.5416   0.7617
#  DcisionTreeClassifier    0.6481 0.5034   0.7082
# RandomForestClassifier    0.9171 0.5336   0.7524
#               LightGBM    0.7645 0.5776   0.7733
